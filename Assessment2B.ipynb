# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv('college_1.csv')

# %%
df2 = pd.read_csv('college_2.csv')

# %%
new_df = pd.concat([df1,df2], axis=0)
new_df.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
x = new_df['python_en'].mode()
new_df['python_en'].fillna(x[0], inplace=True)
y = new_df['computational_thinking'].mode()
new_df['computational_thinking'].fillna(y[0], inplace=True)

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
exceeded_df= new_df[new_df["CodeKata Score"] > 15000]
exceeded_df.to_csv("Exceeded expectations.csv", index = False)

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
reached_df= new_df[((new_df["CodeKata Score"]>10000) & (new_df["CodeKata Score"]<15000))]
reached_df.to_csv("Reached_expectations.csv", index = False)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
needs_improvement_df= new_df[((new_df["CodeKata Score"]>7000) & (new_df["CodeKata Score"]<10000))]
needs_improvement_df.to_csv("Needs_improvement.csv", index = False)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory_df= new_df[new_df["CodeKata Score"]>7000]
Unsatisfactory_df.to_csv("Unsatisfactory.csv", index = False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
pr_week=new_df["CodeKata Score"].mean()
print(pr_week)
this_week=new_df["Previous Geekions"].mean()
this_week
# Out:
# 4051.764705882353
# 3842.3529411764707

# %% [markdown]
# ###### No of students participated

# %%
new_df["Name"].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
Avrg_completion=new_df[((new_df["python"] == 100.0)|(new_df["mysql"] == 100)|(new_df["python_en"] == 100)|(new_df["computational_thinking"] == 100))]
Avrg_completion
# Out:
#                           Name  python   mysql  Previous Geekions  \
# 2                  HEMAVATHI.R   100.0  100.00              19680
# 3                  Mugunthan S   100.0   47.00              10610
# 4                  Sathammai.S   100.0    8.00               8980
# 5                 NIVEESHWAR S   100.0    0.00               8200
# 11                Ponniyamma.R   100.0   11.25               5380
# 12                   SABAPATHI   100.0    0.00               5280
# 13                    RAGHAVAN   100.0    0.00               5120
# 15                    Pavithra   100.0  100.00               4600
# 17                 v.vithyasri   100.0   12.00               4370
# 18          Abirami Anbazhagan   100.0    0.00               4320
# 19                S.srinivasan   100.0   12.00               4090
# 20                    s.janani   100.0    0.00               3915
# 22                     Yuvasri   100.0  100.00               3460
# ...

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
new_df.nlargest(3, "Rising")['Name']
# Out:
# 8              shifak N
# 2     Ganesh Ramkumar R
# 18       Narasimhan Y L
# Name: Name, dtype: object

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
new_df.nlargest(3, "CodeKata Score")['Name']
# Out:
# 0      A.Dharani
# 1    V.JEEVITHA
# 2    HEMAVATHI.R
# Name: Name, dtype: object

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
x = new_df["Department"].value_counts().rename_axis("No_of_department").reset_index(name ='count')
x
# Out:
#                             No_of_department  count
# 0           Computer Science and Engineering     63
# 1  Electronics and Communication Engineering     39
# 2     Electronics and Electrical Engineering     17

# %%
explode = (0.13, 0.13, 0.13)
plt.figure(figsize=(9,6))

new_df.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score', autopct='%1.2f%%', explode=explode,shadow =True,
       startangle=150)
plt.axis('equal')
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
toppers = new_df.groupby(['Department']).max()
toppers
# Out:
#                                                      Name  python  mysql  \
# Department
# Computer Science and Engineering              vijayakumar   100.0  100.0
# Electronics and Communication Engineering       vignesh B   100.0  100.0
# Electronics and Electrical Engineering     yaser ahamed.A   100.0  100.0
#
#                                            Previous Geekions  CodeKata Score  \
# Department
# Computer Science and Engineering                       24500           24500
# Electronics and Communication Engineering              10040           10040
# Electronics and Electrical Engineering                 19400           19400
#
#                                            Rising  python_en  \
# Department
# Computer Science and Engineering             2000       78.0
# Electronics and Communication Engineering     560       72.0
# Electronics and Electrical Engineering       3140      100.0
#
#                                            computational_thinking
# ...

# %%
x = toppers.plot.bar(stacked = True)
